# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
air = pd.read_csv('/Users/manishwagle/Desktop/AIR QUALITY INTELLIGENCE/data/raw/air.csv')
weather = pd.read_csv('/Users/manishwagle/Desktop/AIR QUALITY INTELLIGENCE/data/raw/weather.csv')

# %%
air.head()
# Out:
#                time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-08-04T00:00          21.4           15.0                      364
# 1  2022-08-04T01:00          18.7           13.2                      353
# 2  2022-08-04T02:00          16.1           11.3                      338
# 3  2022-08-04T03:00          16.7           11.7                      313
# 4  2022-08-04T04:00          17.3           12.2                      289
#
#    carbon_dioxide (ppm)  nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  \
# 0                   NaN                       7.2                      2.8
# 1                   NaN                       6.8                      2.7
# 2                   NaN                       6.4                      2.5
# 3                   NaN                       5.5                      2.2
# 4                   NaN                       4.4                      1.9
#
#    ozone (μg/m³)  ammonia (μg/m³)  us_aqi (USAQI)  uv_index ()
# ...

# %%
air.isnull().sum()
# Out:
# time                            0
# pm10 (μg/m³)                    0
# pm2_5 (μg/m³)                   0
# carbon_monoxide (μg/m³)         0
# carbon_dioxide (ppm)        19536
# nitrogen_dioxide (μg/m³)        0
# sulphur_dioxide (μg/m³)         0
# ozone (μg/m³)                   0
# ammonia (μg/m³)             27384
# us_aqi (USAQI)                 24
# uv_index ()                     0
# dtype: int64

# %%
air.head(50)
# Out:
#                 time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0   2022-08-04T00:00          21.4           15.0                      364
# 1   2022-08-04T01:00          18.7           13.2                      353
# 2   2022-08-04T02:00          16.1           11.3                      338
# 3   2022-08-04T03:00          16.7           11.7                      313
# 4   2022-08-04T04:00          17.3           12.2                      289
# 5   2022-08-04T05:00          18.1           12.7                      261
# 6   2022-08-04T06:00          19.8           13.9                      233
# 7   2022-08-04T07:00          17.1           12.0                      224
# 8   2022-08-04T08:00          18.2           12.8                      221
# 9   2022-08-04T09:00          16.4           11.5                      223
# 10  2022-08-04T10:00          13.9            9.7                      218
# ...

# %%
air = air.iloc[24:,:]

# %%
air.drop(columns =['carbon_dioxide (ppm)','ammonia (μg/m³)'],inplace=True)

# %%
air.isnull().sum()
# Out:
# time                        0
# pm10 (μg/m³)                0
# pm2_5 (μg/m³)               0
# carbon_monoxide (μg/m³)     0
# nitrogen_dioxide (μg/m³)    0
# sulphur_dioxide (μg/m³)     0
# ozone (μg/m³)               0
# us_aqi (USAQI)              0
# uv_index ()                 0
# dtype: int64

# %%
weather.isnull().sum()
# Out:
# time                               0
# temperature_2m (°C)               23
# relative_humidity_2m (%)          23
# wind_direction_10m (°)            23
# precipitation (mm)                23
# surface_pressure (hPa)            23
# pressure_msl (hPa)                23
# wind_speed_10m (km/h)             23
# wind_gusts_10m (km/h)             23
# soil_moisture_0_to_7cm (m³/m³)    23
# soil_temperature_0_to_7cm (°C)    23
# cloud_cover (%)                   23
# dtype: int64

# %%
weather.tail(50)
# Out:
#                    time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 27334  2025-09-15T22:00                 19.6                      96.0
# 27335  2025-09-15T23:00                 19.6                      94.0
# 27336  2025-09-16T00:00                 19.2                      95.0
# 27337  2025-09-16T01:00                 20.3                      97.0
# 27338  2025-09-16T02:00                 21.0                      96.0
# 27339  2025-09-16T03:00                 21.4                      95.0
# 27340  2025-09-16T04:00                 22.0                      85.0
# 27341  2025-09-16T05:00                 22.0                      95.0
# 27342  2025-09-16T06:00                 22.1                      96.0
# 27343  2025-09-16T07:00                 22.7                      96.0
# 27344  2025-09-16T08:00                 22.6                      92.0
# 27345  2025-09-16T09:00                 23.0                      81.0
# ...

# %%
weather = weather.iloc[:27361,:]

# %%
weather.isnull().sum()
# Out:
# time                              0
# temperature_2m (°C)               0
# relative_humidity_2m (%)          0
# wind_direction_10m (°)            0
# precipitation (mm)                0
# surface_pressure (hPa)            0
# pressure_msl (hPa)                0
# wind_speed_10m (km/h)             0
# wind_gusts_10m (km/h)             0
# soil_moisture_0_to_7cm (m³/m³)    0
# soil_temperature_0_to_7cm (°C)    0
# cloud_cover (%)                   0
# dtype: int64

# %%
weather.head()
# Out:
#                time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0  2022-08-04T00:00                 20.5                      94.0
# 1  2022-08-04T01:00                 21.3                      91.0
# 2  2022-08-04T02:00                 21.9                      90.0
# 3  2022-08-04T03:00                 22.7                      87.0
# 4  2022-08-04T04:00                 24.5                      83.0
#
#    wind_direction_10m (°)  precipitation (mm)  surface_pressure (hPa)  \
# 0                   153.0                 0.3                   869.8
# 1                   157.0                 0.5                   871.0
# 2                   112.0                 0.0                   871.8
# 3                    72.0                 0.0                   871.9
# 4                    16.0                 0.1                   872.6
#
#    pressure_msl (hPa)  wind_speed_10m (km/h)  wind_gusts_10m (km/h)  \
# 0              1008.4                    2.4                   13.0
# ...

# %%
air.head()
# Out:
#                 time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 24  2022-08-05T00:00          31.7           22.2                      478
# 25  2022-08-05T01:00          29.7           20.8                      435
# 26  2022-08-05T02:00          25.3           17.7                      374
# 27  2022-08-05T03:00          23.1           16.2                      303
# 28  2022-08-05T04:00          20.3           14.2                      272
#
#     nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)  \
# 24                      14.1                      5.2             68
# 25                      11.6                      4.5             75
# 26                       8.2                      3.5             85
# 27                       4.3                      2.5             97
# 28                       2.9                      2.0            103
#
#     us_aqi (USAQI)  uv_index ()
# 24            58.0         0.05
# 25            59.0         0.45
# ...

# %%
merged_df = pd.merge(air,weather,how='inner',on='time')

# %%
len(merged_df)
# Out:
# 27337

# %%
merged_df.head()
# Out:
#                time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0  2022-08-05T00:00          31.7           22.2                      478
# 1  2022-08-05T01:00          29.7           20.8                      435
# 2  2022-08-05T02:00          25.3           17.7                      374
# 3  2022-08-05T03:00          23.1           16.2                      303
# 4  2022-08-05T04:00          20.3           14.2                      272
#
#    nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)  \
# 0                      14.1                      5.2             68
# 1                      11.6                      4.5             75
# 2                       8.2                      3.5             85
# 3                       4.3                      2.5             97
# 4                       2.9                      2.0            103
#
#    us_aqi (USAQI)  uv_index ()  temperature_2m (°C)  relative_humidity_2m (%)  \
# ...

# %%
merged_df.tail()
# Out:
#                    time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 27332  2025-09-16T20:00          10.3           10.3                      351
# 27333  2025-09-16T21:00           9.7            9.7                      338
# 27334  2025-09-16T22:00          10.1           10.1                      363
# 27335  2025-09-16T23:00          10.0           10.0                      413
# 27336  2025-09-17T00:00           1.7            1.7                      453
#
#        nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  ozone (μg/m³)  \
# 27332                      11.1                      6.7             59
# 27333                       9.4                      5.9             62
# 27334                       8.4                      5.2             65
# 27335                       7.9                      4.6             68
# 27336                       5.3                      2.5             70
#
#        us_aqi (USAQI)  uv_index ()  temperature_2m (°C)  \
# ...

# %%
merged_df.isnull().sum()
# Out:
# time                              0
# pm10 (μg/m³)                      0
# pm2_5 (μg/m³)                     0
# carbon_monoxide (μg/m³)           0
# nitrogen_dioxide (μg/m³)          0
# sulphur_dioxide (μg/m³)           0
# ozone (μg/m³)                     0
# us_aqi (USAQI)                    0
# uv_index ()                       0
# temperature_2m (°C)               0
# relative_humidity_2m (%)          0
# wind_direction_10m (°)            0
# precipitation (mm)                0
# surface_pressure (hPa)            0
# pressure_msl (hPa)                0
# wind_speed_10m (km/h)             0
# wind_gusts_10m (km/h)             0
# soil_moisture_0_to_7cm (m³/m³)    0
# soil_temperature_0_to_7cm (°C)    0
# cloud_cover (%)                   0
# dtype: int64

# %%
df_numeric = merged_df.drop(columns=['time'])

plt.figure(figsize=(12, 10))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
merged_df['Date'] = pd.to_datetime(merged_df['time']).dt.date
merged_df['Time'] = pd.to_datetime(merged_df['time']).dt.time

# %%
merged_df = merged_df.drop(columns=['time'])
merged_df['Datetime'] = pd.to_datetime(merged_df['Date'].astype(str) + ' ' + merged_df['Time'].astype(str))
columns = ['Datetime'] + [col for col in merged_df.columns if col not in ['Datetime', 'Date', 'Time']]
merged_df = merged_df[columns]

# %%
merged_df = merged_df.rename(columns={
    'pm10 (μg/m³)': 'PM10 (μg/m³)',
    'pm2_5 (μg/m³)': 'PM2.5 (μg/m³)',
    'carbon_monoxide (μg/m³)': 'CO (μg/m³)',
    'nitrogen_dioxide (μg/m³)': 'NO2 (μg/m³)',
    'ozone (μg/m³)': 'O3 (μg/m³)',
    'uv_index ()': 'UV_Index',
    'sulphur_dioxide (μg/m³)': 'SO2 (μg/m³)',
    'temperature_2m (°C)': 'Temp (°C)',
    'relative_humidity_2m (%)': 'Humidity (%)',
    'wind_direction_10m (°)': 'Wind_Direction (°)',
    'wind_speed_10m (km/h)': 'Wind_Speed (km/h)',
    'precipitation (mm)': 'Precipitation (mm)',
    'surface_pressure (hPa)': 'Surface_Pressure (hPa)',
    'pressure_msl (hPa)': 'Pressure_MSL (hPa)',
    'wind_gusts_10m (km/h)': 'Wind_Gusts (km/h)',
    'soil_moisture_0_to_7cm (m³/m³)': 'Soil_Moisture (m³/m³)',
    'soil_temperature_0_to_7cm (°C)': 'Soil_Temp (°C)',
    'cloud_cover (%)': 'Cloud_Cover (%)',
    'us_aqi (USAQI)': 'AQI'
})

# %%
merged_df.head()
# Out:
#              Datetime  PM10 (μg/m³)  PM2.5 (μg/m³)  CO (μg/m³)  NO2 (μg/m³)  \
# 0 2022-08-05 00:00:00          31.7           22.2         478         14.1
# 1 2022-08-05 01:00:00          29.7           20.8         435         11.6
# 2 2022-08-05 02:00:00          25.3           17.7         374          8.2
# 3 2022-08-05 03:00:00          23.1           16.2         303          4.3
# 4 2022-08-05 04:00:00          20.3           14.2         272          2.9
#
#    SO2 (μg/m³)  O3 (μg/m³)   AQI  UV_Index  Temp (°C)  Humidity (%)  \
# 0          5.2          68  58.0      0.05       20.3          98.0
# 1          4.5          75  59.0      0.45       21.0          96.0
# 2          3.5          85  59.0      1.65       21.7          93.0
# 3          2.5          97  60.0      3.80       23.2          86.0
# 4          2.0         103  60.0      6.15       25.1          76.0
#
#    Wind_Direction (°)  Precipitation (mm)  Surface_Pressure (hPa)  \
# ...

# %%
zero_values = {}
for i in merged_df.columns:
    zero_values[i] = merged_df[merged_df[i] == 0]
    print(f"{i}: {len(zero_values[i])}")
# Out:
# Datetime: 0
# PM10 (μg/m³): 0
# PM2.5 (μg/m³): 0
# CO (μg/m³): 0
# NO2 (μg/m³): 423
# SO2 (μg/m³): 2
# O3 (μg/m³): 0
# AQI: 0
# UV_Index: 14029
# Temp (°C): 0
# Humidity (%): 0
# Wind_Direction (°): 0
# Precipitation (mm): 20376
# Surface_Pressure (hPa): 0
# Pressure_MSL (hPa): 0
# Wind_Speed (km/h): 57
# Wind_Gusts (km/h): 0
# Soil_Moisture (m³/m³): 0
# Soil_Temp (°C): 0
# Cloud_Cover (%): 5449

# %%
# Visualizing O3 (Ozone) levels over time because even though UV_Index has many 0 values but it doesnot and hence verifying if the trend is present or not
plt.plot(merged_df['O3 (μg/m³)'])

# %%
merged_df.head()
# Out:
#              Datetime  PM10 (μg/m³)  PM2.5 (μg/m³)  CO (μg/m³)  NO2 (μg/m³)  \
# 0 2022-08-05 00:00:00          31.7           22.2         478         14.1
# 1 2022-08-05 01:00:00          29.7           20.8         435         11.6
# 2 2022-08-05 02:00:00          25.3           17.7         374          8.2
# 3 2022-08-05 03:00:00          23.1           16.2         303          4.3
# 4 2022-08-05 04:00:00          20.3           14.2         272          2.9
#
#    SO2 (μg/m³)  O3 (μg/m³)   AQI  UV_Index  Temp (°C)  Humidity (%)  \
# 0          5.2          68  58.0      0.05       20.3          98.0
# 1          4.5          75  59.0      0.45       21.0          96.0
# 2          3.5          85  59.0      1.65       21.7          93.0
# 3          2.5          97  60.0      3.80       23.2          86.0
# 4          2.0         103  60.0      6.15       25.1          76.0
#
#    Wind_Direction (°)  Precipitation (mm)  Surface_Pressure (hPa)  \
# ...

# %%
merged_df.drop(columns =['Soil_Moisture (m³/m³)'	,'Soil_Temp (°C)'],inplace=True)

# %%
merged_df.to_csv('/Users/manishwagle/Desktop/AIR QUALITY INTELLIGENCE/data/processed/processed_data.csv',index=False)
